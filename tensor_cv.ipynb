# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

data = tf.keras.datasets.fashion_mnist

(training_images, training_labels), (test_images, test_labels) = data.load_data()

training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
model = Sequential(
    [
        Flatten(input_shape=(28, 28)), 
        Dense(128, activation=tf.nn.relu), #relu = rectified linear unit -> The activation function is the code that will execute on each neuron in the layer.
        Dense(10, activation=tf.nn.softmax)
    ]
  )

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2817 - accuracy: 0.8970
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2683 - accuracy: 0.9002
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2580 - accuracy: 0.9050
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2477 - accuracy: 0.9071
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2364 - accuracy: 0.9118

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3416 - accuracy: 0.8830
# [0.34156832098960876, 0.8830000162124634]

# %%
classifications = model.predict(test_images)
print(classifications[9999])
print(test_labels[9999])
# Out:
# [2.5455143e-05 3.7097672e-09 5.4050229e-06 9.5784245e-08 1.6811591e-05
#  9.7456974e-01 2.2604912e-05 2.4781916e-02 5.5345666e-04 2.4541916e-05]
# 5
