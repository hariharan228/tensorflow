# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten

data = tf.keras.datasets.fashion_mnist
(training_images, training_labels),(testing_images, testing_labels) = data.load_data()

# %%
training_images = training_images.reshape(60000, 28, 28, 1)
training_images = training_images / 255.0
testing_images = testing_images.reshape(10000, 28, 28, 1)
testing_images = testing_images / 255.0

# %%
model = Sequential(
    [
      Conv2D(10, (3, 3), activation='relu', input_shape=(28, 28, 1)),
      MaxPooling2D(2, 2),
      Conv2D(64, (3, 3), activation='relu'),
      MaxPooling2D(2,2),
      Flatten(),
      Dense(128, activation=tf.nn.relu),
      Dense(10, activation=tf.nn.softmax)
    ]
  )

# %%
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(training_images, training_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 20s 10ms/step - loss: 2.3028 - accuracy: 0.0972
# Epoch 2/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 2.3028 - accuracy: 0.0995
# Epoch 3/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 2.3028 - accuracy: 0.0998
# Epoch 4/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 2.3028 - accuracy: 0.0993
# Epoch 5/5
# 1875/1875 [==============================] - 19s 10ms/step - loss: 2.3028 - accuracy: 0.0971

# %%
model.evaluate(testing_images, testing_labels)
classifications = model.predict(testing_images)
print(classifications[0])
print(testing_labels[0])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 2.3027 - accuracy: 0.1000
# [0.10135462 0.09889621 0.10097305 0.09965274 0.09995487 0.09755258
#  0.10188427 0.10110357 0.09895568 0.09967242]
# 9

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 26, 26, 10)        100
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 10)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 64)        5824
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1600)              0
#
#  dense_4 (Dense)             (None, 128)               204928
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 212,142
# Trainable params: 212,142
# Non-trainable params: 0
# _________________________________________________________________
